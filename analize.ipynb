# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3 as sl

# %% [markdown]
# Загрузим собранные данные из базы:

# %%
con = sl.connect('db/parse_habr.db')

# %%
df = pd.read_sql("""
                SELECT * FROM DATA_SCIENCE               
                """, con)

# %%
df.head()
# Out:
#        user_name                     date  \
# 0      Dasha_icc   8 февраля 2018 в 13:34
# 1   apostteriori  26 августа 2019 в 15:43
# 2        MegaFon      26 мая 2020 в 12:14
# 3  X5RetailGroup  25 февраля 2020 в 14:30
# 4           mngr     18 июля 2018 в 11:28
#
#                                                title likes  \
# 0  7 бесплатных курсов по Data Science для начина...   +17
# 1  Moscow Data Science Major August 2019: програм...   +31
# 2                               Квиз, плиз! BIG DATA    +8
# 3  29 февраля в ЦДП состоится X5 RetailHero: как ...    +7
# 4        4 года Data Science в Schibsted Media Group    +7
#
#                                                 tags  \
# 0   Блог компании icanchoose.ru,Data Mining,Big Data
# 1  Блог компании Mail.ru Group,Big Data,Машинное ...
# 2  Блог компании «МегаФон»,Big Data,Логические иг...
# 3       Big Data,Искусственный интеллект,IT-компании
# 4  Data Mining,Big Data,Машинное обучение,Управле...
#
# ...

# %%
df
# Out:
#               user_name                      date  \
# 0             Dasha_icc    8 февраля 2018 в 13:34
# 1          apostteriori   26 августа 2019 в 15:43
# 2               MegaFon       26 мая 2020 в 12:14
# 3         X5RetailGroup   25 февраля 2020 в 14:30
# 4                  mngr      18 июля 2018 в 11:28
# ...                 ...                       ...
# 1006          Nordavind  26 сентября 2013 в 14:17
# 1007          lockywolf   14 октября 2013 в 15:59
# 1008               itmo    3 февраля 2016 в 18:57
# 1009  anastasiagrishina    5 октября 2016 в 18:21
# 1010          Schvepsss       17 мая 2017 в 11:29
#
#                                                   title likes  \
# 0     7 бесплатных курсов по Data Science для начина...   +17
# 1     Moscow Data Science Major August 2019: програм...   +31
# 2                                  Квиз, плиз! BIG DATA    +8
# 3     29 февраля в ЦДП состоится X5 RetailHero: как ...    +7
# ...
